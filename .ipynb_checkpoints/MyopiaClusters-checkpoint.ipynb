# %%
#Imports

import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# # Prep Data

# %%
# Load data
file = Path('myopia.csv')

# %%
#Read data
df = pd.read_csv(file, index_col=0)
df.head(10)
# Out:
#      SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  STUDYHR  \
# AGE
# 6   -0.052  21.889999  3.690  3.498  14.70       45       8       0        0
# 6    0.608  22.379999  3.702  3.392  15.29        4       0       1        1
# 6    1.179  22.490000  3.462  3.514  15.52       14       0       2        0
# 6    0.525  22.200001  3.862  3.612  14.73       18      11       0        0
# 5    0.697  23.290001  3.676  3.454  16.16       14       0       0        0
# 6    1.744  22.139999  3.224  3.556  15.36       10       6       2        1
# 6    0.683  22.330000  3.186  3.654  15.49       12       7       2        1
# 6    1.272  22.389999  3.732  3.584  15.08       12       0       0        0
# 7    1.396  22.620001  3.464  3.408  15.74        4       0       3        1
# 6    0.972  22.740000  3.504  3.696  15.54       30       5       1        0
#
#      TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# AGE
# 6      10         34      1      1       1
# ...

# %%
myopiaDF = df.drop("MYOPIC", axis=1)
myopiaDF
# Out:
#      SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  STUDYHR  \
# AGE
# 6   -0.052  21.889999  3.690  3.498  14.70       45       8       0        0
# 6    0.608  22.379999  3.702  3.392  15.29        4       0       1        1
# 6    1.179  22.490000  3.462  3.514  15.52       14       0       2        0
# 6    0.525  22.200001  3.862  3.612  14.73       18      11       0        0
# 5    0.697  23.290001  3.676  3.454  16.16       14       0       0        0
# ..     ...        ...    ...    ...    ...      ...     ...     ...      ...
# 6    0.678  22.400000  3.663  3.803  14.93        2       0       7        3
# 6    0.665  22.500000  3.570  3.378  15.56        6       0       1        0
# 6    1.834  22.940001  3.624  3.424  15.89        8       0       0        0
# 6    0.665  21.920000  3.688  3.598  14.64       12       2       1        0
# 6    0.802  22.260000  3.530  3.484  15.25       25       0       2        0
#
#      TVHR  DIOPTERHR  MOMMY  DADMY
# ...

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(myopiaDF)

# %% [markdown]
# # Apply Dimensionality Reduction

# %%
pca = PCA(n_components=0.90)
myopiaPCA = pca.fit_transform(myopiaDF)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.7264387 , 0.16102972, 0.07236347])

# %%
tsne = TSNE(learning_rate=50)
transformedFeatures = tsne.fit_transform(myopiaPCA)

# %%
transformed_features.shape
# Out:
# (618, 2)

# %%
myopiaDF["X"] = transformedFeatures[:,0]
myopiaDF["y"] = transformedFeatures[:,1]
myopiaDF["Myopic"] = df["MYOPIC"]

# %%
#x and y on scatter
plt.scatter(myopiaDF["X"], myopiaDF["y"])
plt.show()

# %%
#x and y with Myopic data to compare
plt.scatter(myopiaDF["X"], myopiaDF["y"], c=myopiaDF["Myopic"])
plt.show()

# %%
#count of unique values
labels = myopiaDF["Myopic"]
labels.value_counts()
# Out:
# 0    537
# 1     81
# Name: Myopic, dtype: int64

# %% [markdown]
# # Cluster Analysis

# %%
myopiaEndResult = pd.DataFrame(data=myopiaPCA, 
                             columns=["principal component 1", "principal component 2",
                                      "principal component 3"])
myopiaEndResult.head()
# Out:
#    principal component 1  principal component 2  principal component 3
# 0              12.142776              31.635516              -4.530655
# 1             -15.265886              -6.095797               1.206298
# 2             -11.659399               3.754895               2.807076
# 3              11.240358               4.011894              -8.184388
# 4             -22.432358               4.579498              -1.826268

# %%
inertia = []
k = list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(myopiaEndResult)
    inertia.append(km.inertia_)

# %%
#Elbow Curve
elbow = {"k": k, "inertia": inertia}
ElbowDF = pd.DataFrame(elbow)

# %%
#plot the curve
plt.plot(ElbowDF['k'], ElbowDF['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
ElbowDF.head()
# Out:
#    k        inertia
# 0  1  224306.459926
# 1  2  116544.075450
# 2  3   83538.494374
# 3  4   68663.412801
# 4  5   57628.953868

# %% [markdown]
# Recommendation: Patients could be grouped in three clusters
